# %%
import tkinter as tk


class InternshipChecker:
    def __init__(self, master):
        self.master = master
        master.title("Internship Checker")

        # Labels and Entries for personal information
        self.name_label = tk.Label(master, text="Name:")
        self.name_label.pack()
        self.name_entry = tk.Entry(master)
        self.name_entry.pack()

        self.age_label = tk.Label(master, text="Age:")
        self.age_label.pack()
        self.age_entry = tk.Entry(master)
        self.age_entry.pack()

        self.education_label = tk.Label(master, text="Education:")
        self.education_label.pack()
        self.education_entry = tk.Entry(master)
        self.education_entry.pack()

        # Button to check eligibility for an internship
        self.check_button = tk.Button(
            master, text="Check Eligibility", command=self.check_eligibility)
        self.check_button.pack()

        # Label to display the result
        self.result_label = tk.Label(master, text="")
        self.result_label.pack()

    def check_eligibility(self):
        # Retrieve values from entries
        name = self.name_entry.get()
        age = int(self.age_entry.get())
        education = self.education_entry.get()

        # Check eligibility based on criteria
        if age >= 18 and "college" in education.lower():
            message = f"{name}, you are eligible for the internship!"
        else:
            message = f"Sorry {name}, you are not eligible for the internship."

        # Display result
        self.result_label.config(text=message)


# Create self-window
root = tk.Tk()

# Instantiate InternshipChecker object
app = InternshipChecker(root)

# Start main event loop
root.mainloop()

# %%
import tkinter as tk


class InternshipChecker:
    def __init__(self, master):
        self.master = master
        master.title("Internship Checker")

        # Labels and Entries for personal information
        self.first_name_label = tk.Label(master, text="First Name:")
        self.first_name_label.pack()
        self.first_name_entry = tk.Entry(master)
        self.first_name_entry.pack()

        self.last_name_label = tk.Label(master, text="Last Name:")
        self.last_name_label.pack()
        self.last_name_entry = tk.Entry(master)
        self.last_name_entry.pack()

        self.major_label = tk.Label(master, text="Major:")
        self.major_label.pack()
        self.major_entry = tk.Entry(master)
        self.major_entry.pack()

        self.credits_label = tk.Label(master, text="Credits:")
        self.credits_label.pack()
        self.credits_entry = tk.Entry(master)
        self.credits_entry.pack()

        # Button to check eligibility for an internship
        self.check_button = tk.Button(
            master, text="Check Eligibility", command=self.check_eligibility)
        self.check_button.pack()

        # Label to display the result
        self.result_label = tk.Label(master, text="")
        self.result_label.pack()

    def check_eligibility(self):
        # Retrieve values from entries
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        major = self.major_entry.get()
        credits = int(self.credits_entry.get())

        # Check eligibility based on criteria
        if credits >= 155 and major.lower() == "IT":
            message = f"{first_name} {last_name}, you are eligible for the internship!"
        else:
            message = f"Sorry {first_name} {last_name}, you are not eligible for the internship."

        # Display result
        self.result_label.config(text=message)


# Create self-window
root = tk.Tk()

# Instantiate InternshipChecker object
app = InternshipChecker(root)

# Start main event loop
root.mainloop()

# %%
import tkinter as tk


class InternshipChecker:
    def __init__(self, master):
        self.master = master
        master.title("Internship Checker")
        master.geometry("400x200")

        # Labels and Entries for personal information
        self.first_name_label = tk.Label(master, text="First Name:")
        self.first_name_label.pack()
        self.first_name_entry = tk.Entry(master)
        self.first_name_entry.pack()

        self.last_name_label = tk.Label(master, text="Last Name:")
        self.last_name_label.pack()
        self.last_name_entry = tk.Entry(master)
        self.last_name_entry.pack()

        self.major_label = tk.Label(master, text="Major:")
        self.major_label.pack()
        self.major_entry = tk.Entry(master)
        self.major_entry.pack()

        self.credits_label = tk.Label(master, text="Credits:")
        self.credits_label.pack()
        self.credits_entry = tk.Entry(master)
        self.credits_entry.pack()

        # Button to check eligibility for an internship
        self.check_button = tk.Button(
            master, text="Check Eligibility", command=self.check_eligibility)
        self.check_button.pack()

        # Label to display the result
        self.result_label = tk.Label(
            master, text="", font=("Arial", 14, "bold"), pady=20)
        self.result_label.pack()

    def check_eligibility(self):
        # Retrieve values from entries
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        major = self.major_entry.get()
        credits = int(self.credits_entry.get())

        # Check eligibility based on criteria
        if credits >= 125 and major.lower() == "computer science":
            message = f"Congratulations {first_name} {last_name}, you are eligible for an internship!\nThe Minimum credits for the internship is 125"
        else:
            message = f"Sorry {first_name} {last_name}, you are not eligible for an internship.\nThe Minimum credits for the internship is 125"

        # Display result
        self.result_label.config(text=message)


# Create self-window
root = tk.Tk()

# Instantiate InternshipChecker object
app = InternshipChecker(root)

# Start main event loop
root.mainloop()

# %%
import tkinter as tk


class InternshipChecker:
    def __init__(self, master):
        self.master = master
        master.title("Internship Checker")
        master.geometry("400x400")

        # Labels and Entries for personal information
        self.first_name_label = tk.Label(master, text="First Name:")
        self.first_name_label.pack()
        self.first_name_entry = tk.Entry(master)
        self.first_name_entry.pack()

        self.last_name_label = tk.Label(master, text="Last Name:")
        self.last_name_label.pack()
        self.last_name_entry = tk.Entry(master)
        self.last_name_entry.pack()

        self.major_label = tk.Label(master, text="Major:")
        self.major_label.pack()
        self.major_entry = tk.Entry(master)
        self.major_entry.pack()

        self.credits_label = tk.Label(master, text="Credits:")
        self.credits_label.pack()
        self.credits_entry = tk.Entry(master)
        self.credits_entry.pack()

        # Button to check eligibility for an internship
        self.check_button = tk.Button(
            master, text="Check Eligibility", command=self.check_eligibility)
        self.check_button.pack()

        # Label to display the result
        self.result_label = tk.Label()
        self.result_label.pack()

    def check_eligibility(self):
        # Retrieve values from entries
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        major = self.major_entry.get()
        credits = int(self.credits_entry.get())

        # Check eligibility based on criteria
        if credits >= 125 and major.lower() == "it":
            message = f"Congratulations {first_name} {last_name}, you are eligible for an internship!\nThe Minimum credits for the internship is 125"
        else:
            message = f"Sorry {first_name} {last_name}, you are not eligible for an internship.\nThe Minimum credits for the internship is 125"

        # Display result
        self.result_label.config(text=message)


# Create self-window
root = tk.Tk()

# Instantiate InternshipChecker object
app = InternshipChecker(root)

# Start main event loop
root.mainloop()

# %%
import tkinter as tk


class InternshipChecker:
    def __init__(self, master):
        self.master = master
        master.title("Internship Checker")
        master.geometry("400x200")

        # Labels and Entries for personal information
        self.first_name_label = tk.Label(master, text="First Name:")
        self.first_name_label.pack(side=tk.LEFT)
        self.first_name_entry = tk.Entry(master)
        self.first_name_entry.pack(side=tk.RIGHT)

        self.last_name_label = tk.Label(master, text="Last Name:")
        self.last_name_label.pack(side=tk.LEFT)
        self.last_name_entry = tk.Entry(master)
        self.last_name_entry.pack(side=tk.RIGHT)

        self.major_label = tk.Label(master, text="Major:")
        self.major_label.pack(side=tk.LEFT)
        self.major_entry = tk.Entry(master)
        self.major_entry.pack(side=tk.RIGHT)

        self.credits_label = tk.Label(master, text="Credits:")
        self.credits_label.pack(side=tk.LEFT)
        self.credits_entry = tk.Entry(master)
        self.credits_entry.pack(side=tk.RIGHT)

        # Button to check eligibility for an internship
        self.check_button = tk.Button(
            master, text="Check Eligibility", command=self.check_eligibility)
        self.check_button.pack()

        # Label to display the result
        self.result_label = tk.Label(
            master, text="", font=("Arial", 14, "bold"), pady=20)
        self.result_label.pack()

    def check_eligibility(self):
        # Retrieve values from entries
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        major = self.major_entry.get()
        credits = int(self.credits_entry.get())

        # Check eligibility based on criteria
        if credits >= 125 and major.lower() == "it":
            message = f"Congratulations {first_name} {last_name}, you are eligible for an internship!\nThe Minimum credits for the internship is 125"
        else:
            message = f"Sorry {first_name} {last_name}, you are not eligible for an internship.\nThe Minimum credits for the internship is 125"

        # Display result
        self.result_label.config(text=message)


# Create self-window
root = tk.Tk()

# Instantiate InternshipChecker object
app = InternshipChecker(root)

# Start main event loop
root.mainloop()

# %%
import tkinter as tk


class InternshipChecker:
    def __init__(self, master):
        self.master = master
        master.title("Internship Checker")
        master.geometry("400x400")

        # Labels and Entries for personal information
        self.first_name_label = tk.Label(master, text="First Name:")
        self.first_name_label.pack(side=tk.LEFT)
        self.first_name_entry = tk.Entry(master)
        self.first_name_entry.pack(side=tk.LEFT, fill=tk.BOTH, expand=tk.YES)

        self.last_name_label = tk.Label(master, text="Last Name:")
        self.last_name_label.pack(side=tk.LEFT)
        self.last_name_entry = tk.Entry(master)
        self.last_name_entry.pack(side=tk.LEFT, fill=tk.BOTH, expand=tk.YES)

        self.major_label = tk.Label(master, text="Major:")
        self.major_label.pack(side=tk.LEFT)
        self.major_entry = tk.Entry(master)
        self.major_entry.pack(side=tk.LEFT, fill=tk.BOTH, expand=tk.YES)

        self.credits_label = tk.Label(master, text="Credits:")
        self.credits_label.pack(side=tk.LEFT)
        self.credits_entry = tk.Entry(master)
        self.credits_entry.pack(side=tk.LEFT, fill=tk.BOTH, expand=tk.YES)

        # Button to check eligibility for an internship
        self.check_button = tk.Button(
            master, text="Check Eligibility", command=self.check_eligibility)
        self.check_button.pack(pady=10)

        # Label to display the result
        self.result_label = tk.Label(
            master, text="", font=("Arial", 14, "bold"))
        self.result_label.pack(side=tk.TOP, fill=tk.BOTH,
                               expand=tk.YES, padx=20, pady=20)

        # Prevent window from resizing to fit widgets
        master.pack_propagate(False)

    def check_eligibility(self):
        # Retrieve values from entries
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        major = self.major_entry.get()
        credits = int(self.credits_entry.get())

        # Check eligibility based on criteria
        if credits >= 125 and major.lower() == "it":
            message = f"Congratulations {first_name} {last_name}, you are eligible for an internship!\nThe Minimum credits for the internship is 125"
        else:
            message = f"Sorry {first_name} {last_name}, you are not eligible for an internship.\nThe Minimum credits for the internship is 125"

        # Display result
        self.result_label.config(text=message)


# Create self-window
root = tk.Tk()

# Start main event loop
app = InternshipChecker(root)
root.mainloop()

# %%
import tkinter as tk


class InternshipChecker:
    def __init__(self, master):
        self.master = master
        master.title("Internship Checker")
        master.geometry("400x400")

        # Labels and Entries for personal information
        self.first_name_label = tk.Label(master, text="First Name:")
        self.first_name_label.pack()
        self.first_name_entry = tk.Entry(master)
        self.first_name_entry.pack()

        self.last_name_label = tk.Label(master, text="Last Name:")
        self.last_name_label.pack()
        self.last_name_entry = tk.Entry(master)
        self.last_name_entry.pack()

        self.major_label = tk.Label(master, text="Major:")
        self.major_label.pack()
        self.major_entry = tk.Entry(master)
        self.major_entry.pack()

        self.credits_label = tk.Label(master, text="Credits:")
        self.credits_label.pack()
        self.credits_entry = tk.Entry(master)
        self.credits_entry.pack()

        # Button to check eligibility for an internship
        self.check_button = tk.Button(
            master, text="Check Eligibility", command=self.check_eligibility)
        self.check_button.pack()

        # Label to display the result
        self.result_label = tk.Label()
        self.result_label.pack()


    def check_eligibility(self):
        # Retrieve values from entries
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        major = self.major_entry.get()
        try:
            credits = int(self.credits_entry.get())
        except ValueError:
            self.result_label.config(
                text="Please enter a valid integer value for Credits.")
            return

        # Check eligibility based on criteria
        if credits >= 125 and major.lower() == "it":
            message = f"Congratulations {first_name} {last_name}, you are eligible for an internship!\nThe Minimum credits for the internship is 125"
        else:
            message = f"Sorry {first_name} {last_name}, you are not eligible for an internship.\nThe Minimum credits for the internship is 125"

        # Display result
        self.result_label.config(text=message)


# Create self-window
root = tk.Tk()

# Instantiate InternshipChecker object
app = InternshipChecker(root)

# Start main event loop
root.mainloop()

# %%
import tkinter as tk
import tkinter.ttk as ttk



class InternshipChecker:
    def __init__(self, master):
        self.master = master
        master.title("Internship Checker")
        master.geometry("400x400")

        # Set the theme
        style = ttk.Style()
        style.theme_use("clam")

        # Labels and Entries for personal information
        self.first_name_label = tk.Label(master, text="First Name:")
        self.first_name_label.pack()
        self.first_name_entry = tk.Entry(master)
        self.first_name_entry.pack()

        self.last_name_label = tk.Label(master, text="Last Name:")
        self.last_name_label.pack()
        self.last_name_entry = tk.Entry(master)
        self.last_name_entry.pack()

        self.major_label = tk.Label(master, text="Major:")
        self.major_label.pack()
        self.major_entry = tk.Entry(master)
        self.major_entry.pack()

        self.credits_label = tk.Label(master, text="Credits:")
        self.credits_label.pack()
        self.credits_entry = tk.Entry(master)
        self.credits_entry.pack()

        # Button to check eligibility for an internship
        self.check_button = tk.Button(
            master, text="Check Eligibility", command=self.check_eligibility)
        self.check_button.pack()

        # Label to display the result
        self.result_label = tk.Label()
        self.result_label.pack()

    def check_eligibility(self):
        # Retrieve values from entries
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        major = self.major_entry.get()
        try:
            credits = int(self.credits_entry.get())
        except ValueError:
            self.result_label.config(
                text="Please enter a valid integer value for Credits.")
            return

        # Check eligibility based on criteria
        if credits >= 125 and major.lower() == "it":
            message = f"Congratulations {first_name} {last_name}, you are eligible for an internship!\nThe Minimum credits for the internship is 125"
        else:
            message = f"Sorry {first_name} {last_name}, you are not eligible for an internship.\nThe Minimum credits for the internship is 125"

        # Display result
        self.result_label.config(text=message)


# Create self-window
root = tk.Tk()

# Instantiate InternshipChecker object
app = InternshipChecker(root)

# Start main event loop
root.mainloop()
